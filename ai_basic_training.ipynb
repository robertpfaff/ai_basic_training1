# %% [markdown]
# # AI Basic Training
#
# Welcome to AI Basic Training! This notebook introduces fundamental AI and machine learning concepts using Python.

# %% [markdown]
# ## Setup
#
# First, let's import the libraries we'll need.

# %%
import numpy as np
import matplotlib.pyplot as plt

print('Libraries imported successfully!')

# %% [markdown]
# ## 1. Linear Regression
#
# Linear regression is one of the simplest machine learning algorithms. It models the relationship between a dependent variable and one or more independent variables.

# %%
# Generate sample data
np.random.seed(42)
X = np.linspace(0, 10, 100)
y = 2 * X + 1 + np.random.randn(100) * 2

# Compute linear regression coefficients using least squares
X_mean = np.mean(X)
y_mean = np.mean(y)
slope = np.sum((X - X_mean) * (y - y_mean)) / np.sum((X - X_mean) ** 2)
intercept = y_mean - slope * X_mean

print(f'Slope: {slope:.2f}')
print(f'Intercept: {intercept:.2f}')

# Plot the results
plt.figure(figsize=(8, 5))
plt.scatter(X, y, alpha=0.5, label='Data')
plt.plot(X, slope * X + intercept, color='red', label='Regression line')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear Regression Example')
plt.legend()
plt.show()

# %% [markdown]
# ## 2. Simple Neural Network Concept
#
# A neural network is inspired by the human brain. It consists of layers of interconnected nodes (neurons). Here we demonstrate a simple activation function.

# %%
# Sigmoid activation function
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# ReLU activation function
def relu(x):
    return np.maximum(0, x)

x = np.linspace(-5, 5, 200)

plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plt.plot(x, sigmoid(x), color='blue')
plt.title('Sigmoid Activation')
plt.xlabel('x')
plt.ylabel('sigmoid(x)')
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(x, relu(x), color='green')
plt.title('ReLU Activation')
plt.xlabel('x')
plt.ylabel('relu(x)')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Next Steps
#
# Now that you've seen the basics, here are some topics to explore further:
#
# - **Classification** – Logistic Regression, Decision Trees, Support Vector Machines
# - **Clustering** – K-Means, DBSCAN
# - **Deep Learning** – CNNs, RNNs, Transformers
# - **Libraries** – scikit-learn, TensorFlow, PyTorch
#
# Happy learning! 🚀
